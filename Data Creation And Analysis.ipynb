# %%
{'Supplier Name': 'Infosys',
 'Region': 'APAC',
 'Country': 'India',
 'Function': 'IT & Infrastructure',
 'Service': 'Applications Development',
 'Avg. Cost($)': '100k',
 'Rating': '90',
 'Average Delivery Time': '90',
 'Number of Escalations': '5',
 'Year': '2018',
 'Resources': '10000'}

# %%
list(df.Brand)
# Out:
# ['Accenture',
#  'IBM (IT Services)',
#  'TCS',
#  'Cognizant',
#  'Infosys',
#  'Capgemini',
#  'DXC Technology',
#  'HCL',
#  'Ntt Data',
#  'Wipro',
#  'Atos',
#  'Samsung SDS',
#  'Fujitsu (IT Services)',
#  'Xerox',
#  'HPE (IT Services)']

# %%
import pandas as pd

df = pd.read_csv('DataSets/brandirectory-ranking-data-it-services-2019.csv')
df.head(30)
# Out:
#                     Brand  Position Previous Position Brand Value ($M)  \
# 0               Accenture         1                 2         26292.38
# 1       IBM (IT Services)         2                 1         20366.93
# 2                     TCS         3                 3         12814.57
# 3               Cognizant         4                 4          8704.19
# 4                 Infosys         5                 5          6500.66
# 5               Capgemini         6                 8          5921.72
# 6          DXC Technology         7                 6          5525.01
# 7                     HCL         8                 7          4648.12
# 8                Ntt Data         9                 -          4266.16
# 9                   Wipro        10                11          4001.75
# 10                   Atos        11                10                🔒
# 11            Samsung SDS        12                 -                🔒
# ...

# %%
old_value = 10000 

old_min = -16000 

old_max = 16000 

new_min = 0 

new_max = 100 

new_value = ( ( 10000 - -16000 ) / (16000 - -16000) ) * (100 - 0) + 0

# %%
new_value = ( (old_value - old_min) / (old_max - old_min) ) * (new_max - new_min) + new_min

# %%
new_value
# Out:
# 81.25

# %%
DataSets\list-of-companies-in-software-industry.csv

# %%
import pandas as pd

df = pd.read_csv('DataSets\list-of-companies-in-software-industry.csv')
Additional1 = list(df['For more information such as company website, company description, industry, CEO, founder, and more upload this file to https://powrbot.com/company-search/ to get the latest information from the web.'])

# %%
List_of_years = [2014+i for i in range(9)]
List_of_years
# Out:
# [2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]

# %%
Companies_set = set()

for i in List_of_years:
    df = pd.read_csv('DataSets/brandirectory-ranking-data-it-services-%s.csv'%(i))
    Curr_List = list(df.Brand)
    for j in Curr_List:
        Companies_set.add(j)

# %%
Companies_set = list(Companies_set)

# %%
print(Companies_set)
# Out:
# ['Bechtle', 'LTI', 'Cap Gemini', 'FIS', 'Ntt Data', 'HCL', 'Samsung SDS', 'Capgemini', 'Fujitsu', 'Tieto', 'EPAM', 'SAIC', 'HP', 'Globant', 'IBM Consulting', 'Fujitsu (IT Services)', 'accenture', 'CGI', 'Accenture', 'DXC Technology', 'Sabre', 'Xerox', 'Bechtle (IT Services)', 'TCS', 'IBM', 'Tech Mahindra', 'Sopra Steria', 'Hewlett Packard Enterprise', 'CTC', 'NEC (IT Services)', 'HPE (IT Services)', 'Thoughtworks', 'Nec', 'Cognizant', 'Conduent', 'Computer Sciences', 'Wipro', 'Infosys', 'Atos', 'IBM (IT Services)']

# %%
New_Companies = []
for i in Companies_set:
    if "(IT Services)" in i:
        New_Companies.append(i.split(" ")[0])
    else:
        New_Companies.append(i)

# %%
print(New_Companies)
print(len(New_Companies))
# Out:
# ['Bechtle', 'LTI', 'Cap Gemini', 'FIS', 'Ntt Data', 'HCL', 'Samsung SDS', 'Capgemini', 'Fujitsu', 'Tieto', 'EPAM', 'SAIC', 'HP', 'Globant', 'IBM Consulting', 'Fujitsu', 'accenture', 'CGI', 'Accenture', 'DXC Technology', 'Sabre', 'Xerox', 'Bechtle', 'TCS', 'IBM', 'Tech Mahindra', 'Sopra Steria', 'Hewlett Packard Enterprise', 'CTC', 'NEC', 'HPE', 'Thoughtworks', 'Nec', 'Cognizant', 'Conduent', 'Computer Sciences', 'Wipro', 'Infosys', 'Atos', 'IBM']
# 40

# %%
print(Additional1)
# Out:
# ['Solium', 'Tyler Technologies', 'Veeva Systems', 'Phoenix Technologies', 'Rave Mobile Safety', 'Sage Software', 'SirsiDynix', 'Smarsh', 'eCopy', 'Modernizing Medicine', 'SAS Institute', 'ModusLink', 'google', 'Google', '\ufeffFullContact', 'Corporate360', 'Hubspot', 'MarkLogic', 'HouseCall', 'Laserfiche', 'TriTech Software Systems', 'fullcontact', 'Lending Club', 'Esri', 'Finastra', 'GOOGL', 'Clarabridge', 'NetManage', 'MontaVista Software', 'Tradeshift', 'Autodesk, Inc.', 'Citrix Systems, Inc.', 'RealNetworks, Inc.', 'DEMANDWARE, INC.', 'Salesforce.com Inc', 'GlobalSCAPE, Inc.', 'MAGIX', 'Salesforce.com', 'Citrix Systems', 'MISYS', 'FIDESSA', 'ANITE', 'PLAYTECH', 'UNIT4', 'GLOBAL GRAPHICS', 'DEMATIC', 'salesforce.com', 'Balabit', 'Salesforce', 'Bede Gaming', 'newstore', 'Atlassian', 'STARLIMS', 'LabWare', 'NUANCE COMMUNICATIONS, INC.', 'AUTODESK INC', 'Tibco Software Inc.', 'SnapLogic', 'TIBCO', 'Tibco', 'Credit Karma', 'GitHub', 'HubSpot', 'Medallia', 'Abacus Data Systems', 'Mitch
# ...

# %%
"C:\Users\hp\Desktop\Personal Projects\Sirion Labs - Hackathon Project\DataSets\list-of-companies-in-india.csv"

# %%
import pandas as pd

df = pd.read_csv('DataSets/list-of-companies-in-india.csv')
Additional2 = list(df['For more information such as company website, company description, industry, CEO, founder, and more upload this file to https://powrbot.com/company-search/ to get the latest information from the web.'])

# %%
print(len(Additional2))
# Out:
# 141476

# %%
New_Companies.extend(Additional1)
New_Companies.extend(Additional2)
New_Companies = list(set(New_Companies))
print(len(New_Companies))
# Out:
# 141666

# %%
{'Supplier Name': 'Infosys',
 'Region': 'APAC',
 'Country': 'India',
 'Function': 'IT & Infrastructure',
 'Service': 'Applications Development',
 'Avg. Cost($)': '100k',
 'Rating': '90',
 'Average Delivery Time': '90',
 'Number of Escalations': '5',
 'Year': '2018',
 'Resources': '10000'}

# %%
Region_List = {
    "Africa" : ['Algeria', 'Angola', 'Benin', 'Botswana', 'Burkina Faso', 'Burundi', 'Cameroon', 'Cape Verde', 'Central African Republic', 'Chad', 'Comoros', "Cote d'Ivoire", 'Democratic Republic of the Congo', 'Djibouti', 'Egypt', 'Equatorial Guinea', 'Eritrea', 'Ethiopia', 'Gabon', 'Gambia', 'Ghana', 'Guinea', 'Guinea-Bissau', 'Kenya', 'Lesotho', 'Liberia', 'Libya', 'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius', 'Morocco', 'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Republic of the Congo', 'Reunion', 'Rwanda', 'Saint Helena', 'Sao Tome and Principe', 'Senegal', 'Seychelles', 'Sierra Leone', 'Somalia', 'South Africa', 'South Sudan', 'Sudan', 'Swaziland', 'Tanzania', 'Togo', 'Tunisia', 'Uganda', 'Western Sahara', 'Zambia', 'Zimbabwe'],
    "Asia": ['Afghanistan', 'Armenia', 'Azerbaijan', 'Bahrain', 'Bangladesh', 'Bhutan', 'Brunei', 'Burma', 'Cambodia', 'China', 'Cyprus', 'East Timor', 'Georgia', 'Hong Kong', 'India', 'Indonesia', 'Iran', 'Iraq', 'Israel', 'Japan', 'Jordan', 'Kazakhstan', 'Kuwait', 'Kyrgyzstan', 'Laos', 'Lebanon', 'Macau', 'Malaysia', 'Maldives', 'Mongolia', 'Nepal', 'North Korea', 'Oman', 'Pakistan', 'Philippines', 'Qatar', 'Saudi Arabia', 'Singapore', 'South Korea', 'Sri Lanka', 'Syria', 'Taiwan', 'Tajikistan', 'Thailand', 'Turkey', 'Turkmenistan', 'United Arab Emirates', 'Uzbekistan', 'Vietnam', 'Yemem'],
    "Caribbean" :['Anguilla', 'Antigua and Barbuda', 'Aruba', 'The Bahamas', 'Barbados', 'Bermuda', 'British Virgin Islands', 'Cayman Islands', 'Cuba', 'Dominica', 'Dominican Republic', 'Grenada', 'Guadeloupe', 'Haiti', 'Jamaica', 'Martinique', 'Montserrat', 'Netherlands Antilles', 'Puerto Rico', 'Saint Kitts and Nevis', 'Saint Lucia', 'Saint Vincent and the Grenadines', 'Trinidad and Tobago', 'Turks and Caicos Islands', 'U.S. Virgin Islands'] ,
    "Central America" : ['Belize', 'Costa Rica', 'El Salvador', 'Guatemala', 'Honduras', 'Nicaragua', 'Panama'],
    "Europe" : ['Albania', 'Andorra', 'Austria', 'Belarus', 'Belgium', 'Bosnia and Herzegovina', 'Bulgaria', 'Croatia', 'Czech Republic', 'Denmark', 'Estonia', 'Finland', 'France', 'Germany', 'Gibraltar', 'Greece', 'Holy See', 'Hungary', 'Iceland', 'Ireland', 'Italy', 'Kosovo', 'Latvia', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Macedonia', 'Malta', 'Moldova', 'Monaco', 'Montenegro', 'Netherlands', 'Norway', 'Poland', 'Portugal', 'Romania', 'Russia', 'San Marino', 'Slovak Republic', 'Slovenia', 'Spain', 'Serbia', 'Serbia and Montenegro', 'Sweden', 'Switzerland', 'Ukraine', 'United Kingdom'],
    "North America" : ['Canada', 'Greenland', 'Mexico', 'Saint Pierre and Miquelon', 'United States', 'Caribbean', 'Central America'],
    "Oceania" : ['American Samoa', 'Australia', 'Christmas Island', 'Cocos (Keeling) Islands', 'Cook Islands', 'Federated States of Micronesia', 'Fiji', 'French Polynesia', 'Guam', 'Kiribati', 'Marshall Islands', 'Nauru', 'New Caledonia', 'New Zealand', 'Niue', 'Northern Mariana Islands', 'Palau', 'Papua New Guinea', 'Pitcairn Islands', 'Samoa', 'Solomon Islands', 'Tokelau', 'Tonga', 'Tuvalu', 'Vanuatu', 'and Wallis', 'Futuna Islands'],
    "South America": ['Argentina', 'Bolivia', 'Brazil', 'Chile', 'Colombia', 'Ecuador', 'Falkland Islands', 'French Guiana', 'Guyana', 'Paraguay', 'Peru', 'Suriname', 'Uruguay', 'Venezuela'] 
}

# %%
import json

# %%
f = json.dumps(Region_List)
with open('Region_List.json' , 'w') as k:
    k.write(f)

# %%
list_countries =  'Argentina, Bolivia, Brazil, Chile, Colombia, Ecuador, Falkland Islands, French Guiana, Guyana, Paraguay, Peru, Suriname, Uruguay, Venezuela'
list_countries = list_countries.split(",")
list_countries = [i.strip() for i in list_countries]
print(list_countries)
# Out:
# ['Argentina', 'Bolivia', 'Brazil', 'Chile', 'Colombia', 'Ecuador', 'Falkland Islands', 'French Guiana', 'Guyana', 'Paraguay', 'Peru', 'Suriname', 'Uruguay', 'Venezuela']

# %%
list_countries = 'Canada, Greenland, Mexico, Saint Pierre and Miquelon, United States,Caribbean, Central America'
list_countries = list_countries.split(",")
list_countries = [i.strip() for i in list_countries]
print(list_countries)
# Out:
# ['Canada', 'Greenland', 'Mexico', 'Saint Pierre and Miquelon', 'United States', 'Caribbean', 'Central America']

# %%
Supplier_List = New_Companies.copy()
Function_List = ["IT & Infrastructure" , "Consulting" , "HR" , "Software" , "Marketing" ,"Insurance" , "Finance" , "Applications Development"]

# %%
import random

# %%
random.choice(list(Region_List.keys()))
# Out:
# 'Africa'

# %%
list_of_years = [2010 + i for i in range(0,13)]
print(list_of_years)
# Out:
# [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]

# %%
{'Supplier Name': 'Infosys',
 'Region': 'APAC',
 'Country': 'India',
 'Function': 'IT & Infrastructure',
 'Service': 'Applications Development',
 'Avg. Cost($)': '100k',
 'Rating': '90',
 'Average Delivery Time': '90',
 'Number of Escalations': '5',
 'Year': '2018',
 'Resources': '10000'}

# %%
len(Supplier_List)
# Out:
# 141666

# %%
print(len(New_Companies))
# Out:
# 141666

# %%
New_Companies[:100]
# Out:
# ['exaspring information services',
#  'purpleslate private limited.',
#  'ortus market research pvt ltd.',
#  'cherri technologies',
#  'palium skills',
#  'koyo sms (india) private limited',
#  'grapes innovative solutions',
#  'bela instruments - india',
#  'laasma power - india',
#  'esquire consultancy services',
#  'eyeforweb',
#  'akulmach technologies',
#  'instalively',
#  'crafters india',
#  'coromandel agro products and oils limited',
#  'tani data services',
#  'infinix360',
#  'impact systems pvt. ltd.',
#  'edoft',
#  'punarnawa crafts pvt. ltd.',
#  'future campus school - india',
#  'ravindra enterprises',
#  'little rose english high school',
#  'parishram resources pvt. ltd.',
#  'vartc',
#  'shriram life insurance',
#  'nividata consultancy',
#  'hcs wellness - building healthy workplaces',
#  'shubham international',
#  'shree venkatesh buildcon pvt ltd',
#  'achernar consulting services llp',
#  'karvy computershare',
#  'stem electronics pvt ltd',
# ...

# %%
Final_Dict_Data = []

# %%
for year in list_of_years:
    for company in New_Companies:
        curr_Dict = {}
        curr_Dict['Supplier Name'] = company
        curr_Dict['Region'] = random.choice(list(Region_List.keys()))
        curr_Dict['Country'] = random.choice(Region_List[curr_Dict['Region']])
        curr_Dict['Function'] = random.choice(Function_List)
        curr_Dict['Avg. Cost($)'] = random.randrange(50,500,50)
        curr_Dict['Rating'] = random.randrange(10,100,10)
        curr_Dict['Average Delivery Time'] = random.randrange(100,1000,10)
        curr_Dict['Number of Escalations'] = random.randrange(5,500,5)
        curr_Dict['Year'] = year
        curr_Dict['Resources'] = random.randrange(1000,10000,1000)
        
        Final_Dict_Data.append(curr_Dict)

# %%
len(Final_Dict_Data)
# Out:
# 1841658

# %%
import time
start = time.time()
for i in Final_Dict_Data:
    a = len(i)
end = time.time()
print(end - start)
# Out:
# 3.532214879989624

# %%
dir(json)
# Out:
# ['JSONDecodeError',
#  'JSONDecoder',
#  'JSONEncoder',
#  '__all__',
#  '__author__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_default_decoder',
#  '_default_encoder',
#  'codecs',
#  'decoder',
#  'detect_encoding',
#  'dump',
#  'dumps',
#  'encoder',
#  'load',
#  'loads',
#  'scanner']

# %%
Json_Storage = dict()

Json_Storage['Data'] = Final_Dict_Data

# %%
print(len(Final_Dict_Data))
# Out:
# 1983520

# %%
import pickle

with open("Final_Data_of_Supplier.pkl" , 'wb') as f:
    pickle.dump(Final_Dict_Data , f)

# %%
f = json.dumps(Json_Storage)
with open("Final_Data_of_Supplier.json" , 'w') as k:
    k.write(f)
print("Done!!")
# Out:
# Done!!

# %%
Final_Dict_Data
# Out:
# [{'Supplier Name': 'exaspring information services',
#   'Region': 'Caribbean',
#   'Country': 'Haiti',
#   'Function': 'Finance',
#   'Avg. Cost($)': 100,
#   'Rating': 70,
#   'Average Delivery Time': 650,
#   'Number of Escalations': 260,
#   'Year': 2010,
#   'Resources': 7000},
#  {'Supplier Name': 'purpleslate private limited.',
#   'Region': 'Caribbean',
#   'Country': 'Puerto Rico',
#   'Function': 'Insurance',
#   'Avg. Cost($)': 450,
#   'Rating': 30,
#   'Average Delivery Time': 820,
#   'Number of Escalations': 290,
#   'Year': 2010,
#   'Resources': 8000},
#  {'Supplier Name': 'ortus market research pvt ltd.',
#   'Region': 'Caribbean',
#   'Country': 'Guadeloupe',
#   'Function': 'Software',
#   'Avg. Cost($)': 50,
#   'Rating': 80,
#   'Average Delivery Time': 510,
#   'Number of Escalations': 25,
#   'Year': 2010,
#   'Resources': 9000},
#  {'Supplier Name': 'cherri technologies',
#   'Region': 'Europe',
#   'Country': 'Andorra',
#   'Function': 'Software',
# ...

# %%
print(len(Final_Dict_Data))
# Out:
# 1983520

# %%
print(len(Final_Dict_Data))
# Out:
# 1841658

# %%
Sample_Working_List = []
for i in Final_Dict_Data:
    if i['Supplier Name'] == 'exaspring information services':
        Sample_Working_List.append(i)

# %%
import pickle

with open("Final_Data_of_Supplier.pkl" , 'wb') as f:
    pickle.dump(Final_Dict_Data , f)

# %%
List_of_years
# Out:
# [2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]

# %%
Avg_Cost = []
Rating = []
for i in Sample_Working_List:
    Avg_Cost.append(i['Avg. Cost($)'])
    Rating.append(i['Rating'])

# %%
print(Sample_Working_List)
# Out:
# [{'Supplier Name': 'exaspring information services', 'Region': 'Caribbean', 'Country': 'Haiti', 'Function': 'Finance', 'Avg. Cost($)': 100, 'Rating': 70, 'Average Delivery Time': 650, 'Number of Escalations': 260, 'Year': 2010, 'Resources': 7000}, {'Supplier Name': 'exaspring information services', 'Region': 'South America', 'Country': 'Uruguay', 'Function': 'Marketing', 'Avg. Cost($)': 150, 'Rating': 20, 'Average Delivery Time': 120, 'Number of Escalations': 370, 'Year': 2011, 'Resources': 8000}, {'Supplier Name': 'exaspring information services', 'Region': 'Central America', 'Country': 'Nicaragua', 'Function': 'Insurance', 'Avg. Cost($)': 450, 'Rating': 80, 'Average Delivery Time': 840, 'Number of Escalations': 170, 'Year': 2012, 'Resources': 8000}, {'Supplier Name': 'exaspring information services', 'Region': 'North America', 'Country': 'Saint Pierre and Miquelon', 'Function': 'HR', 'Avg. Cost($)': 450, 'Rating': 40, 'Average Delivery Time': 780, 'Number of Escalations': 40, 'Year
# ...

# %%
print(Avg_Cost)
print(Rating)
print(len(Avg_Cost))
print(len(Rating))
# Out:
# [100, 150, 450, 450, 250, 250, 350, 100, 50, 50, 150, 250, 450]
# [70, 20, 80, 40, 90, 60, 20, 90, 40, 60, 10, 70, 20]
# 13
# 13

# %%
List_of_years = [2010 + i for i in range(13)]
print(List_of_years)
print(len(List_of_years))
# Out:
# [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# 13

# %%
import matplotlib.pyplot as plt
plt.plot(List_of_years , Avg_Cost)

# %%
import matplotlib.pyplot as plt
plt.plot(List_of_years , Rating)

# %%
-
